# %%
#First of all we import all the related libraries related to project for analysis. 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Reading the csv file using pandas
df = pd.read_csv("C://Users//delli//Downloads//tiktok_dataset.csv")

# %%
#Calling the dataframe using head.Head will show the attributed value in the brackets.
df.head(10)
# Out:
#     # claim_status    video_id  video_duration_sec  \
# 0   1        claim  7017666017                  59
# 1   2        claim  4014381136                  32
# 2   3        claim  9859838091                  31
# 3   4        claim  1866847991                  25
# 4   5        claim  7105231098                  19
# 5   6        claim  8972200955                  35
# 6   7        claim  4958886992                  16
# 7   8        claim  2270982263                  41
# 8   9        claim  5235769692                  50
# 9  10        claim  4660861094                  45
#
#                             video_transcription_text verified_status  \
# 0  someone shared with me that drone deliveries a...    not verified
# 1  someone shared with me that there are more mic...    not verified
# 2  someone shared with me that american industria...    not verified
# 3  someone shared with me that the metro of st. p...    not verified
# 4  someone shared with me that the number of busi...    not verified
# 5  someone shared with me that gross domestic pro...    not verified
# 6  someone shared with me that elvis presley has ...    not verified
# 7  someone shared with me that the best selling s...    not verified
# 8  someone shared with me that about half of the ...    not verified
# 9  someone shared with me that it would take a 50...        verified
#
#   author_ban_status  video_view_count  video_like_count  video_share_count  \
# 0      under review          343296.0           19425.0              241.0
# 1            active          140877.0           77355.0            19034.0
# 2            active          902185.0           97690.0             2858.0
# 3            active          437506.0          239954.0            34812.0
# 4            active           56167.0           34987.0             4110.0
# 5      under review          336647.0          175546.0            62303.0
# 6            active          750345.0          486192.0           193911.0
# 7            active          547532.0            1072.0               50.0
# 8            active           24819.0           10160.0             1050.0
# 9            active          931587.0          171051.0            67739.0
#
#    video_download_count  video_comment_count
# 0                   1.0                  0.0
# 1                1161.0                684.0
# 2                 833.0                329.0
# 3                1234.0                584.0
# 4                 547.0                152.0
# 5                4293.0               1857.0
# 6                8616.0               5446.0
# 7                  22.0                 11.0
# 8                  53.0                 27.0
# 9                4104.0               2540.0

# %%
#columns function will call the names of the columns included in the dataframe.
df.columns
# Out:
# Index(['#', 'claim_status', 'video_id', 'video_duration_sec',
#        'video_transcription_text', 'verified_status', 'author_ban_status',
#        'video_view_count', 'video_like_count', 'video_share_count',
#        'video_download_count', 'video_comment_count'],
#       dtype='object')

# %%
#rename function is used to rename the columns of the the dataframe.
df = df.rename(columns = {'#':'S_no'})
df
# Out:
#         S_no claim_status    video_id  video_duration_sec  \
# 0          1        claim  7017666017                  59
# 1          2        claim  4014381136                  32
# 2          3        claim  9859838091                  31
# 3          4        claim  1866847991                  25
# 4          5        claim  7105231098                  19
# ...      ...          ...         ...                 ...
# 19377  19378          NaN  7578226840                  21
# 19378  19379          NaN  6079236179                  53
# 19379  19380          NaN  2565539685                  10
# 19380  19381          NaN  2969178540                  24
# 19381  19382          NaN  8132759688                  13
#
#                                 video_transcription_text verified_status  \
# 0      someone shared with me that drone deliveries a...    not verified
# 1      someone shared with me that there are more mic...    not verified
# 2      someone shared with me that american industria...    not verified
# 3      someone shared with me that the metro of st. p...    not verified
# 4      someone shared with me that the number of busi...    not verified
# ...                                                  ...             ...
# 19377                                                NaN    not verified
# 19378                                                NaN    not verified
# 19379                                                NaN        verified
# 19380                                                NaN    not verified
# 19381                                                NaN    not verified
#
#       author_ban_status  video_view_count  video_like_count  \
# 0          under review          343296.0           19425.0
# 1                active          140877.0           77355.0
# 2                active          902185.0           97690.0
# 3                active          437506.0          239954.0
# 4                active           56167.0           34987.0
# ...                 ...               ...               ...
# 19377            active               NaN               NaN
# 19378            active               NaN               NaN
# 19379      under review               NaN               NaN
# 19380            active               NaN               NaN
# 19381            active               NaN               NaN
#
#        video_share_count  video_download_count  video_comment_count
# 0                  241.0                   1.0                  0.0
# 1                19034.0                1161.0                684.0
# 2                 2858.0                 833.0                329.0
# 3                34812.0                1234.0                584.0
# 4                 4110.0                 547.0                152.0
# ...                  ...                   ...                  ...
# 19377                NaN                   NaN                  NaN
# 19378                NaN                   NaN                  NaN
# 19379                NaN                   NaN                  NaN
# 19380                NaN                   NaN                  NaN
# 19381                NaN                   NaN                  NaN
#
# [19382 rows x 12 columns]

# %%
#This will tell the shape of the dataframe
df.shape
# Out:
# (19382, 12)

# %%
#Dropna function is used to drop the 'NaN' values in the dataframe.inplace is used to confirm that these changes will directly effect the original dataframe.
df.dropna(inplace = True)

# %%
df
# Out:
#         S_no claim_status    video_id  video_duration_sec  \
# 0          1        claim  7017666017                  59
# 1          2        claim  4014381136                  32
# 2          3        claim  9859838091                  31
# 3          4        claim  1866847991                  25
# 4          5        claim  7105231098                  19
# ...      ...          ...         ...                 ...
# 19079  19080      opinion  1492320297                  49
# 19080  19081      opinion  9841347807                  23
# 19081  19082      opinion  8024379946                  50
# 19082  19083      opinion  7425795014                   8
# 19083  19084      opinion  4094655375                  58
#
#                                 video_transcription_text verified_status  \
# 0      someone shared with me that drone deliveries a...    not verified
# 1      someone shared with me that there are more mic...    not verified
# 2      someone shared with me that american industria...    not verified
# 3      someone shared with me that the metro of st. p...    not verified
# 4      someone shared with me that the number of busi...    not verified
# ...                                                  ...             ...
# 19079  in our opinion the earth holds about 11 quinti...    not verified
# 19080  in our opinion the queens in ant colonies live...    not verified
# 19081  in our opinion the moon is moving away from th...    not verified
# 19082  in our opinion lightning strikes somewhere on ...    not verified
# 19083  in our opinion a pineapple plant can only prod...    not verified
#
#       author_ban_status  video_view_count  video_like_count  \
# 0          under review          343296.0           19425.0
# 1                active          140877.0           77355.0
# 2                active          902185.0           97690.0
# 3                active          437506.0          239954.0
# 4                active           56167.0           34987.0
# ...                 ...               ...               ...
# 19079            active            6067.0             423.0
# 19080            active            2973.0             820.0
# 19081            active             734.0             102.0
# 19082            active            3394.0             655.0
# 19083            active            5034.0             815.0
#
#        video_share_count  video_download_count  video_comment_count
# 0                  241.0                   1.0                  0.0
# 1                19034.0                1161.0                684.0
# 2                 2858.0                 833.0                329.0
# 3                34812.0                1234.0                584.0
# 4                 4110.0                 547.0                152.0
# ...                  ...                   ...                  ...
# 19079               81.0                   8.0                  2.0
# 19080               70.0                   3.0                  0.0
# 19081                7.0                   2.0                  1.0
# 19082              123.0                  11.0                  4.0
# 19083              281.0                  11.0                  1.0
#
# [19084 rows x 12 columns]

# %%
df.shape
# Out:
# (19084, 12)

# %%
df.columns
# Out:
# Index(['S_no', 'claim_status', 'video_id', 'video_duration_sec',
#        'video_transcription_text', 'verified_status', 'author_ban_status',
#        'video_view_count', 'video_like_count', 'video_share_count',
#        'video_download_count', 'video_comment_count'],
#       dtype='object')

# %%
df = df.rename(columns = {'video_duration_sec':'Duration','video_view_count':'Views','video_like_count':'Like','video_share_count':'Share','video_download_count':'Downloads','video_comment_count':'Comments'})
df.head(5)
# Out:
#    S_no claim_status    video_id  Duration  \
# 0     1        claim  7017666017        59
# 1     2        claim  4014381136        32
# 2     3        claim  9859838091        31
# 3     4        claim  1866847991        25
# 4     5        claim  7105231098        19
#
#                             video_transcription_text verified_status  \
# 0  someone shared with me that drone deliveries a...    not verified
# 1  someone shared with me that there are more mic...    not verified
# 2  someone shared with me that american industria...    not verified
# 3  someone shared with me that the metro of st. p...    not verified
# 4  someone shared with me that the number of busi...    not verified
#
#   author_ban_status     Views      Like    Share  Downloads  Comments
# 0      under review  343296.0   19425.0    241.0        1.0       0.0
# 1            active  140877.0   77355.0  19034.0     1161.0     684.0
# 2            active  902185.0   97690.0   2858.0      833.0     329.0
# 3            active  437506.0  239954.0  34812.0     1234.0     584.0
# 4            active   56167.0   34987.0   4110.0      547.0     152.0

# %%
#Drop function is used to drop the columns in the dataframe.Axis indicates that you want to drop the column named.
df = df.drop('video_transcription_text',axis = 1)

# %%
df.head(4)
# Out:
#    S_no claim_status    video_id  Duration verified_status author_ban_status  \
# 0     1        claim  7017666017        59    not verified      under review
# 1     2        claim  4014381136        32    not verified            active
# 2     3        claim  9859838091        31    not verified            active
# 3     4        claim  1866847991        25    not verified            active
#
#       Views      Like    Share  Downloads  Comments
# 0  343296.0   19425.0    241.0        1.0       0.0
# 1  140877.0   77355.0  19034.0     1161.0     684.0
# 2  902185.0   97690.0   2858.0      833.0     329.0
# 3  437506.0  239954.0  34812.0     1234.0     584.0

# %%
#value count is used to count all the unique values in the particular column.
df['claim_status'].value_counts().head(20)
# Out:
# claim_status
# claim      9608
# opinion    9476
# Name: count, dtype: int64

# %%
#astype is used to change the datatype of the column.
df['Views'] = df['Views'].astype(int)
df['Like'] = df['Like'].astype(int)
df['Share'] = df['Share'].astype(int)
df['Downloads'] = df['Downloads'].astype(int)
df['Comments'] = df['Comments'].astype(int)

# %%
#Defining a new variable to contain the dataframe with having duration above 50.
df_filtered = df[df['Duration']>=50]

# %%
df_filtered
# Out:
#         S_no claim_status    video_id  Duration verified_status  \
# 0          1        claim  7017666017        59    not verified
# 8          9        claim  5235769692        50    not verified
# 12        13        claim  3609761483        51    not verified
# 22        23        claim  7986031283        52    not verified
# 23        24        claim  5733649579        54    not verified
# ...      ...          ...         ...       ...             ...
# 19072  19073      opinion  3653523966        56    not verified
# 19073  19074      opinion  4452438809        58    not verified
# 19077  19078      opinion  4635088632        50    not verified
# 19081  19082      opinion  8024379946        50    not verified
# 19083  19084      opinion  4094655375        58    not verified
#
#       author_ban_status   Views    Like  Share  Downloads  Comments
# 0          under review  343296   19425    241          1         0
# 8                active   24819   10160   1050         53        27
# 12               active  700081  434565  97995       2408      1411
# 22               banned   60096   34245  11345        219        77
# 23               active  750942  136252  27119       2637      1206
# ...                 ...     ...     ...    ...        ...       ...
# 19072            active    5760      89     33          0         0
# 19073            active    3184    1328     79         22         4
# 19077            active    3183    1233     95          3         0
# 19081            active     734     102      7          2         1
# 19083            active    5034     815    281         11         1
#
# [3754 rows x 11 columns]

# %%
#plotting a bar chart using plot method
colors = ('blue','cyan','green','magenta','red','yellow')
df_filtered['Duration'].value_counts().plot(kind = 'bar',color = colors,title = 'Videos of Duration Above 50',xlabel = 'Duration',ylabel = 'Count')
# Out:
# <Axes: title={'center': 'Videos of Duration Above 50'}, xlabel='Duration', ylabel='Count'>

# %%
Duration = df_filtered['Duration']

# %%
Duration
# Out:
# 0        59
# 8        50
# 12       51
# 22       52
# 23       54
#          ..
# 19072    56
# 19073    58
# 19077    50
# 19081    50
# 19083    58
# Name: Duration, Length: 3754, dtype: int64

# %%
plt.figure(figsize = (4,5))
plt.bar(Duration,align = 'center',height = 10)
plt.title('Videos of Duration more than 50s',weight = 'bold',color = 'red')
plt.show()

# %%
df
# Out:
#         S_no claim_status    video_id  Duration verified_status  \
# 0          1        claim  7017666017        59    not verified
# 1          2        claim  4014381136        32    not verified
# 2          3        claim  9859838091        31    not verified
# 3          4        claim  1866847991        25    not verified
# 4          5        claim  7105231098        19    not verified
# ...      ...          ...         ...       ...             ...
# 19079  19080      opinion  1492320297        49    not verified
# 19080  19081      opinion  9841347807        23    not verified
# 19081  19082      opinion  8024379946        50    not verified
# 19082  19083      opinion  7425795014         8    not verified
# 19083  19084      opinion  4094655375        58    not verified
#
#       author_ban_status   Views    Like  Share  Downloads  Comments
# 0          under review  343296   19425    241          1         0
# 1                active  140877   77355  19034       1161       684
# 2                active  902185   97690   2858        833       329
# 3                active  437506  239954  34812       1234       584
# 4                active   56167   34987   4110        547       152
# ...                 ...     ...     ...    ...        ...       ...
# 19079            active    6067     423     81          8         2
# 19080            active    2973     820     70          3         0
# 19081            active     734     102      7          2         1
# 19082            active    3394     655    123         11         4
# 19083            active    5034     815    281         11         1
#
# [19084 rows x 11 columns]

# %%
df.shape
# Out:
# (19084, 11)

# %%
df['verified_status'].value_counts().plot(kind = 'bar',color = colors,figsize = (4,4),title = 'Status of Videos')
# Out:
# <Axes: title={'center': 'Status of Videos'}, xlabel='verified_status'>

# %%
df.head(10)
# Out:
#    S_no claim_status    video_id  Duration verified_status author_ban_status  \
# 0     1        claim  7017666017        59    not verified      under review
# 1     2        claim  4014381136        32    not verified            active
# 2     3        claim  9859838091        31    not verified            active
# 3     4        claim  1866847991        25    not verified            active
# 4     5        claim  7105231098        19    not verified            active
# 5     6        claim  8972200955        35    not verified      under review
# 6     7        claim  4958886992        16    not verified            active
# 7     8        claim  2270982263        41    not verified            active
# 8     9        claim  5235769692        50    not verified            active
# 9    10        claim  4660861094        45        verified            active
#
#     Views    Like   Share  Downloads  Comments
# 0  343296   19425     241          1         0
# 1  140877   77355   19034       1161       684
# 2  902185   97690    2858        833       329
# 3  437506  239954   34812       1234       584
# 4   56167   34987    4110        547       152
# 5  336647  175546   62303       4293      1857
# 6  750345  486192  193911       8616      5446
# 7  547532    1072      50         22        11
# 8   24819   10160    1050         53        27
# 9  931587  171051   67739       4104      2540

# %%
df = df.rename(columns = {'author_ban_status':'Ban_status'})

# %%
df
# Out:
#         S_no claim_status    video_id  Duration verified_status    Ban_status  \
# 0          1        claim  7017666017        59    not verified  under review
# 1          2        claim  4014381136        32    not verified        active
# 2          3        claim  9859838091        31    not verified        active
# 3          4        claim  1866847991        25    not verified        active
# 4          5        claim  7105231098        19    not verified        active
# ...      ...          ...         ...       ...             ...           ...
# 19079  19080      opinion  1492320297        49    not verified        active
# 19080  19081      opinion  9841347807        23    not verified        active
# 19081  19082      opinion  8024379946        50    not verified        active
# 19082  19083      opinion  7425795014         8    not verified        active
# 19083  19084      opinion  4094655375        58    not verified        active
#
#         Views    Like  Share  Downloads  Comments
# 0      343296   19425    241          1         0
# 1      140877   77355  19034       1161       684
# 2      902185   97690   2858        833       329
# 3      437506  239954  34812       1234       584
# 4       56167   34987   4110        547       152
# ...       ...     ...    ...        ...       ...
# 19079    6067     423     81          8         2
# 19080    2973     820     70          3         0
# 19081     734     102      7          2         1
# 19082    3394     655    123         11         4
# 19083    5034     815    281         11         1
#
# [19084 rows x 11 columns]

# %%
#Defining a new variable st for containing the count of banned users.
st=df['Ban_status'].value_counts()

# %%
print(st)
# Out:
# Ban_status
# active          15383
# under review     2066
# banned           1635
# Name: count, dtype: int64

# %%
'''Converting the st variable firstly into dictionary using dict() method.Secondly converting the keys and values seperatly into list using list() method.
This is done to plot a pie chart which will help in understanding the data.'''
l = dict(st)
print(l)
l2 = list(l.keys())
l2
l3 = list(l.values())
l3
# Out:
# {'active': 15383, 'under review': 2066, 'banned': 1635}
# [15383, 2066, 1635]

# %%
#Printing the lists
print(l2)
print(l3)
# Out:
# ['active', 'under review', 'banned']
# [15383, 2066, 1635]

# %%
#Plotting the pie chart.
plt.figure(figsize = (4,4))
plt.pie(l3,labels = l2)
plt.axis('equal')
plt.title('Ban_Status of Tik Tok Influencers')
plt.show()

# %%
df
# Out:
#         S_no claim_status    video_id  Duration verified_status    Ban_status  \
# 0          1        claim  7017666017        59    not verified  under review
# 1          2        claim  4014381136        32    not verified        active
# 2          3        claim  9859838091        31    not verified        active
# 3          4        claim  1866847991        25    not verified        active
# 4          5        claim  7105231098        19    not verified        active
# ...      ...          ...         ...       ...             ...           ...
# 19079  19080      opinion  1492320297        49    not verified        active
# 19080  19081      opinion  9841347807        23    not verified        active
# 19081  19082      opinion  8024379946        50    not verified        active
# 19082  19083      opinion  7425795014         8    not verified        active
# 19083  19084      opinion  4094655375        58    not verified        active
#
#         Views    Like  Share  Downloads  Comments
# 0      343296   19425    241          1         0
# 1      140877   77355  19034       1161       684
# 2      902185   97690   2858        833       329
# 3      437506  239954  34812       1234       584
# 4       56167   34987   4110        547       152
# ...       ...     ...    ...        ...       ...
# 19079    6067     423     81          8         2
# 19080    2973     820     70          3         0
# 19081     734     102      7          2         1
# 19082    3394     655    123         11         4
# 19083    5034     815    281         11         1
#
# [19084 rows x 11 columns]

# %%
#Finding the mean of comments column.
df['Comments'].mean()
# Out:
# 349.3121463005659

# %%
df['Downloads'].mean()
# Out:
# 1049.4296269125969

# %%
df['Share'].median()
# Out:
# 717.0

# %%
df.to_excel('Tik Tok Analysis.xlsx')
