# %%
import kaggle
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("C://Users//delli//Downloads//h1b_kaggle.csv//h1b_kaggle.csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0          CASE_STATUS  \
# 0           1  CERTIFIED-WITHDRAWN
# 1           2  CERTIFIED-WITHDRAWN
# 2           3  CERTIFIED-WITHDRAWN
# 3           4  CERTIFIED-WITHDRAWN
# 4           5            WITHDRAWN
#
#                                        EMPLOYER_NAME  \
# 0                             UNIVERSITY OF MICHIGAN
# 1                             GOODMAN NETWORKS, INC.
# 2                          PORTS AMERICA GROUP, INC.
# 3  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CASE_STATUS', 'EMPLOYER_NAME', 'SOC_NAME', 'JOB_TITLE',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'YEAR', 'WORKSITE', 'lon',
#        'lat'],
#       dtype='object')

# %%
df.drop(columns = {'Unnamed: 0'},inplace = True)

# %%
df
# Out:
#                  CASE_STATUS  \
# 0        CERTIFIED-WITHDRAWN
# 1        CERTIFIED-WITHDRAWN
# 2        CERTIFIED-WITHDRAWN
# 3        CERTIFIED-WITHDRAWN
# 4                  WITHDRAWN
# ...                      ...
# 3002453                  NaN
# 3002454                  NaN
# 3002455                  NaN
# 3002456                  NaN
# 3002457                  NaN
#
#                                              EMPLOYER_NAME  \
# 0                                   UNIVERSITY OF MICHIGAN
# 1                                   GOODMAN NETWORKS, INC.
# 2                                PORTS AMERICA GROUP, INC.
# 3        GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                                PEABODY INVESTMENTS CORP.
# ...                                                    ...
# 3002453                                                NaN
# 3002454                                                NaN
# 3002455                                                NaN
# ...

# %%
df.columns = df.columns.str.lower()

# %%
df
# Out:
#                  case_status  \
# 0        CERTIFIED-WITHDRAWN
# 1        CERTIFIED-WITHDRAWN
# 2        CERTIFIED-WITHDRAWN
# 3        CERTIFIED-WITHDRAWN
# 4                  WITHDRAWN
# ...                      ...
# 3002453                  NaN
# 3002454                  NaN
# 3002455                  NaN
# 3002456                  NaN
# 3002457                  NaN
#
#                                              employer_name  \
# 0                                   UNIVERSITY OF MICHIGAN
# 1                                   GOODMAN NETWORKS, INC.
# 2                                PORTS AMERICA GROUP, INC.
# 3        GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                                PEABODY INVESTMENTS CORP.
# ...                                                    ...
# 3002453                                                NaN
# 3002454                                                NaN
# 3002455                                                NaN
# ...

# %%
df.shape[0]
# Out:
# 3002458

# %%
df.dropna(inplace = True)

# %%
df.head(5)
# Out:
#            case_status                                      employer_name  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                         soc_name                     job_title  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
#   full_time_position  prevailing_wage    year                 worksite  \
# ...

# %%
df.reset_index(inplace = True,drop = True)

# %%
df.head(4)
# Out:
#            case_status                                      employer_name  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
#
#                         soc_name                     job_title  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
#
#   full_time_position  prevailing_wage    year                 worksite  \
# 0                  N          36067.0  2016.0      ANN ARBOR, MICHIGAN
# 1                  Y         242674.0  2016.0             PLANO, TEXAS
# ...

# %%
df.shape[0]
# Out:
# 2877765

# %%
emp_bar = df['employer_name'].value_counts().head(15)

# %%
de = dict(emp_bar)

# %%
category = list(de.keys())
values = list(de.values())

# %%
#Plotting the chart

# %%
paint = ['red', 'blue', 'green','black', 'purple', 'pink','orange', 'cyan', 'magenta', 'brown','grey', 'gold', 'lime', 'navy']
plt.figure(figsize = (5,3))
plt.bar(category,values,color = paint,width = 0.4)
plt.title('Top 15 Hiring Companies',fontweight = "bold")
plt.xticks(rotation = 90)
plt.xlabel('categories')
plt.ylabel('values')
plt.show()

# %%
df.head(4)
# Out:
#            case_status                                      employer_name  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
#
#                         soc_name                     job_title  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
#
#   full_time_position  prevailing_wage    year                 worksite  \
# 0                  N          36067.0  2016.0      ANN ARBOR, MICHIGAN
# 1                  Y         242674.0  2016.0             PLANO, TEXAS
# ...

# %%
avg_wage = df['prevailing_wage'].mean()
print(avg_wage)
# Out:
# 145166.64888401062

# %%
df.columns
# Out:
# Index(['case_status', 'employer_name', 'soc_name', 'job_title',
#        'full_time_position', 'prevailing_wage', 'year', 'worksite', 'lon',
#        'lat'],
#       dtype='object')

# %%
df_bar = df['worksite'].value_counts().head(20)

# %%
chart = dict(df_bar)

# %%
plt.figure(figsize = (5,4))
plt.bar(chart.keys(),chart.values(),width = 0.4,color = paint)
plt.xticks(rotation = 90)
plt.xlabel('Worksites')
plt.ylabel('Values')
plt.title('Top 20 Worksites According to Data',fontweight = 'bold')
plt.show()

# %%
df.columns
# Out:
# Index(['case_status', 'employer_name', 'soc_name', 'job_title',
#        'full_time_position', 'prevailing_wage', 'year', 'worksite', 'lon',
#        'lat'],
#       dtype='object')

# %%
df['worksite'] = df['worksite'].apply(lambda x:x.split(',')[-1].strip())

# %%
df.head(10)
# Out:
#            case_status                                      employer_name  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
# 5  CERTIFIED-WITHDRAWN                            BURGER KING CORPORATION
# 6  CERTIFIED-WITHDRAWN                   BT AND MK ENERGY AND COMMODITIES
# 7  CERTIFIED-WITHDRAWN                    GLOBO MOBILE TECHNOLOGIES, INC.
# 8            WITHDRAWN                          LESSARD INTERNATIONAL LLC
# 9  CERTIFIED-WITHDRAWN                                 H.J. HEINZ COMPANY
#
#                         soc_name  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS
# 1               CHIEF EXECUTIVES
# 2               CHIEF EXECUTIVES
# ...

# %%
df['worksite'].fillna("Marina Islands",inplace = True)

# %%
df.head(10)
# Out:
#            case_status                                      employer_name  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
# 5  CERTIFIED-WITHDRAWN                            BURGER KING CORPORATION
# 6  CERTIFIED-WITHDRAWN                   BT AND MK ENERGY AND COMMODITIES
# 7  CERTIFIED-WITHDRAWN                    GLOBO MOBILE TECHNOLOGIES, INC.
# 8            WITHDRAWN                          LESSARD INTERNATIONAL LLC
# 9  CERTIFIED-WITHDRAWN                                 H.J. HEINZ COMPANY
#
#                         soc_name  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS
# 1               CHIEF EXECUTIVES
# 2               CHIEF EXECUTIVES
# ...

# %%
byy = df['worksite'].unique()

# %%
a = list(byy)

# %%
count = 0
for i in a:
    count+=1
print(f"There are total {count} unique records in worksite column")
# Out:
# There are total 53 unique records in worksite column

# %%
df.columns
# Out:
# Index(['case_status', 'employer_name', 'soc_name', 'job_title',
#        'full_time_position', 'prevailing_wage', 'year', 'worksite', 'lon',
#        'lat'],
#       dtype='object')

# %%
df = df.rename(columns = {'employer_name':'EMPLOYER','full_time_position':'FULL_T','prevailing_wage':'PREV_WAGE','worksite':'STATE','lon':'LON','lat':'LAT'})

# %%
df.columns = df.columns.str.lower()

# %%
df
# Out:
#                  case_status  \
# 0        CERTIFIED-WITHDRAWN
# 1        CERTIFIED-WITHDRAWN
# 2        CERTIFIED-WITHDRAWN
# 3        CERTIFIED-WITHDRAWN
# 4                  WITHDRAWN
# ...                      ...
# 2877760            WITHDRAWN
# 2877761            WITHDRAWN
# 2877762            WITHDRAWN
# 2877763            WITHDRAWN
# 2877764            WITHDRAWN
#
#                                                   employer  \
# 0                                   UNIVERSITY OF MICHIGAN
# 1                                   GOODMAN NETWORKS, INC.
# 2                                PORTS AMERICA GROUP, INC.
# 3        GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                                PEABODY INVESTMENTS CORP.
# ...                                                    ...
# 2877760                               ORACLE AMERICA, INC.
# 2877761                                 B & D DENTAL CORP.
# 2877762                  MEDTECH STAFFING & SOLUTIONS, INC
# ...

# %%
df['lon'] = df['lon'].round(2)

# %%
df['lat'] = df['lat'].round(2)

# %%
df.head(4)
# Out:
#            case_status                                           employer  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
#
#                         soc_name                     job_title full_t  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW      N
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER      Y
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER      Y
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS      Y
#
#    prev_wage    year       state     lon    lat
# 0    36067.0  2016.0    MICHIGAN  -83.74  42.28
# 1   242674.0  2016.0       TEXAS  -96.70  33.02
# 2   193066.0  2016.0  NEW JERSEY  -74.08  40.73
# 3   220314.0  2016.0    COLORADO -104.99  39.74

# %%
df['year'] = df['year'].astype('string')

# %%
df['prev_wage'] = df['prev_wage'].astype('int')

# %%
df.dtypes
# Out:
# case_status            object
# employer               object
# soc_name               object
# job_title              object
# full_t                 object
# prev_wage               int32
# year           string[python]
# state                  object
# lon                   float64
# lat                   float64
# dtype: object

# %%
df.head(5)
# Out:
#            case_status                                           employer  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                         soc_name                     job_title full_t  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW      N
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER      Y
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER      Y
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS      Y
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA      Y
#
#    prev_wage    year       state     lon    lat
# 0      36067  2016.0    MICHIGAN  -83.74  42.28
# ...

# %%
df['case_status'].unique()
# Out:
# array(['CERTIFIED-WITHDRAWN', 'WITHDRAWN', 'CERTIFIED', 'DENIED',
#        'REJECTED', 'INVALIDATED',
#        'PENDING QUALITY AND COMPLIANCE REVIEW - UNASSIGNED'], dtype=object)

# %%
new = df['case_status'].value_counts().head(4)

# %%
how= dict(new)
print(how)
# Out:
# {'CERTIFIED': 2512114, 'CERTIFIED-WITHDRAWN': 195721, 'DENIED': 85161, 'WITHDRAWN': 84752}

# %%
plt.figure(figsize = (3,3))
plt.pie(how.values(),labels = how.keys(),colors = paint)
plt.axis('equal')
plt.title('Top 4 case_status',fontweight = 'light')
plt.show()

# %%
barr = df['year'].value_counts()

# %%
bar1 = dict(barr)

# %%
plt.figure(figsize = (13,3))
plt.bar(bar1.keys(),bar1.values(),color = paint)
plt.title('Year Wise Petition Count')
plt.xlabel('Year')
plt.ylabel('Counts')
plt.show()

# %%
den = df[df['case_status']=='DENIED']
len(den)
# Out:
# 85161

# %%
del den['case_status']

# %%
den =den.reset_index()

# %%
den.head(5)
# Out:
#    index                       employer          soc_name  \
# 0     37                PARALLELS, INC.  CHIEF EXECUTIVES
# 1     44           RANCHO LA PUERTA LLC  CHIEF EXECUTIVES
# 2     87            BAKER & MCKENZIE PC  CHIEF EXECUTIVES
# 3     90  MANITOWOC FSG OPERATIONS, LLC  CHIEF EXECUTIVES
# 4    100  TMS PLUMBING AND HEATING CORP  CHIEF EXECUTIVES
#
#                                            job_title full_t  prev_wage  \
# 0                            CHIEF EXECUTIVE OFFICER      Y     187200
# 1                                          PRESIDENT      Y     197683
# 2  PRINCIPAL (ATTORNEY) AND CHAIRMAN OF THE EXECU...      Y     226699
# 3                                VP DIGITAL STRATEGY      Y     202363
# 4                                OPERATIONS DIRECTOR      Y      74276
#
#      year       state     lon    lat
# 0  2016.0  WASHINGTON -122.22  47.48
# 1  2016.0  CALIFORNIA -117.16  32.72
# 2  2016.0    ILLINOIS  -87.63  41.88
# ...

# %%
den.shape
# Out:
# (85161, 10)

# %%
d1 = den['state'].unique()

# %%
a = list(d1)

# %%
counts = 0
for i in a:
    counts+=1
print(counts)
# Out:
# 53

# %%
d2 = df['state'].value_counts().head(25)

# %%
make = dict(d2)

# %%
plt.figure(figsize = (13,5))
plt.bar(make.keys(),make.values(),color = paint,width = 0.4)
plt.title('Total Filed Petition',fontweight = 'bold')
plt.xlabel('States')
plt.ylabel('Counts')
plt.xticks(rotation = 90)
plt.show()

# %%
den['state'].count()
# Out:
# 85161

# %%
last = den['state'].value_counts().head(25)

# %%
lats = dict(last)

# %%
plt.figure(figsize = (13,5))
plt.bar(lats.keys(),lats.values(),color = paint,width = 0.4)
plt.title('Total Petitions Denied',fontweight = 'bold')
plt.xlabel('States')
plt.ylabel('Counts')
plt.xticks(rotation = 90)
plt.show()

# %%
great=df['job_title'].value_counts().head(25)

# %%
greet = dict(great)

# %%
plt.figure(figsize = (5,3))
plt.scatter(greet.keys(),greet.values())
plt.xticks(rotation = 90)
plt.gca().xaxis.set_major_locator(plt.MultipleLocator(0.2))
plt.gca().yaxis.set_major_locator(plt.MultipleLocator(0.2)) 
plt.show()
# Out:
# Locator attempting to generate 1283356 ticks ([-1647.0000000000002, ..., 255024.0]), which exceeds Locator.MAXTICKS (1000).
