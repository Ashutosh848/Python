# %%
import pandas as pd

# %%
df = pd.read_csv("C://Users//delli//Downloads//LOTR.csv")
df1 = pd.read_csv("C://Users//delli//Downloads//LOTR 2.csv")

# %%
df
# Out:
#    FellowshipID FirstName     Skills
# 0          1001     Frodo     Hiding
# 1          1002   Samwise  Gardening
# 2          1003   Gandalf     Spells
# 3          1004    Pippin  Fireworks

# %%
#Inner merge returns only values which are present in both the sets .For ex it will only return the common values from both te sets.
df.merge(df1,how = "inner")
# Out:
#    FellowshipID FirstName     Skills  Age
# 0          1001     Frodo     Hiding   50
# 1          1002   Samwise  Gardening   39

# %%
##Outer merge returns the value of both sets including null values.
df.merge(df1,how = 'outer')
# Out:
#    FellowshipID FirstName     Skills     Age
# 0          1001     Frodo     Hiding    50.0
# 1          1002   Samwise  Gardening    39.0
# 2          1003   Gandalf     Spells     NaN
# 3          1004    Pippin  Fireworks     NaN
# 4          1006   Legolas        NaN  2931.0
# 5          1007    Elrond        NaN  6520.0
# 6          1008  Barromir        NaN    51.0

# %%
#Left merge will return all the values from left (first Table) and the common values from table 2.
df.merge(df1,how = 'left')
# Out:
#    FellowshipID FirstName     Skills   Age
# 0          1001     Frodo     Hiding  50.0
# 1          1002   Samwise  Gardening  39.0
# 2          1003   Gandalf     Spells   NaN
# 3          1004    Pippin  Fireworks   NaN

# %%
#This table will return all the values from right (2nd table) and common rows from the first table
df.merge(df1,how = 'right')
# Out:
#    FellowshipID FirstName     Skills   Age
# 0          1001     Frodo     Hiding    50
# 1          1002   Samwise  Gardening    39
# 2          1006   Legolas        NaN  2931
# 3          1007    Elrond        NaN  6520
# 4          1008  Barromir        NaN    51

# %%
new = pd.read_csv("C://Users//delli//Downloads//df3.pivot_table(df3,values = 'Age',index = 'First... - df3.pivot_table(df3,values = 'Age',index = 'First....csv")

# %%
# Out:
#   FirstName  Skills  Age
# 0     Alice  Python   25
# 1       Bob  Python   30
# 2   Charlie    Java   28
# 3   Charlie  Python   27

# %%
new.drop('Age',axis = 1)
# Out:
#   FirstName  Skills  Fashion
# 0     Alice  Python      NaN
# 1       Bob  Python      NaN
# 2   Charlie    Java      NaN
# 3   Charlie  Python      NaN

# %%
new = new.drop('Age',axis = 1)

# %%
# Out:
#   FirstName  Skills  Fashion
# 0     Alice  Python      NaN
# 1       Bob  Python      NaN
# 2   Charlie    Java      NaN
# 3   Charlie  Python      NaN

# %%
d = {'name':'ashutosh','class':12,'course':'regex','voted':'no','trainer':'Tushar'}
d['name']='Ashu'
print(d)
# Out:
# {'name': 'Ashu', 'class': 12, 'course': 'regex', 'voted': 'no', 'trainer': 'Tushar'}

# %%
s = {1,2,3,3,4,5,5,91823,13,1237,273}
s1 = {1,21,1938,182}
print(s)
s.discard(91823)
print(s)
s.update([12])
print(s)
s.pop()
print(s)
# Out:
# {1, 2, 3, 4, 5, 13, 91823, 273, 1237}
# {1, 2, 3, 4, 5, 13, 273, 1237}
# {1, 2, 3, 4, 5, 12, 13, 273, 1237}
# {2, 3, 4, 5, 12, 13, 273, 1237}

# %%
e = {1,2,3,4,5}
f = {1,2,3,4,5,6,7}
e.union(f)
e.intersection(f)
# Out:
# {1, 2, 3, 4, 5}

# %%
f.issubset(e)
# Out:
# False

# %%
e.issubset(f)
# Out:
# True

# %%
n = 1
while(n<=10):
    print(i)
# Out:
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# ...
