# %%
#First of all we import all the related libraries related to project for analysis. 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Reading the csv file using pandas
df = pd.read_csv("C://Users//delli//Downloads//tiktok_dataset.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 #Reading the csv file using pandas
# ----> 2 df = pd.read_csv("C://Users//delli//Downloads//tiktok_dataset.csv")
#
# File D:\Anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File D:\Anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File D:\Anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File D:\Anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File D:\Anaconda3\Lib\site-packages\pandas\io\common.py:718, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     715     codecs.lookup_error(errors)
#     717 # open URLs
# --> 718 ioargs = _get_filepath_or_buffer(
#     719     path_or_buf,
#     720     encoding=encoding,
#     721     compression=compression,
#     722     mode=mode,
#     723     storage_options=storage_options,
#     724 )
#     726 handle = ioargs.filepath_or_buffer
#     727 handles: list[BaseBuffer]
#
# File D:\Anaconda3\Lib\site-packages\pandas\io\common.py:420, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     415     pass
#     417 try:
#     418     file_obj = fsspec.open(
#     419         filepath_or_buffer, mode=fsspec_mode, **(storage_options or {})
# --> 420     ).open()
#     421 # GH 34626 Reads from Public Buckets without Credentials needs anon=True
#     422 except tuple(err_types_to_retry_with_anon):
#
# File D:\Anaconda3\Lib\site-packages\fsspec\core.py:132, in OpenFile.open(self)
#     125 def open(self):
#     126     """Materialise this as a real open file without context
#     127
#     128     The OpenFile object should be explicitly closed to avoid enclosed file
#     129     instances persisting. You must, therefore, keep a reference to the OpenFile
#     130     during the life of the file-like it generates.
#     131     """
# --> 132     return self.__enter__()
#
# File D:\Anaconda3\Lib\site-packages\fsspec\core.py:100, in OpenFile.__enter__(self)
#      97 def __enter__(self):
#      98     mode = self.mode.replace("t", "").replace("b", "") + "b"
# --> 100     f = self.fs.open(self.path, mode=mode)
#     102     self.fobjects = [f]
#     104     if self.compression is not None:
#
# File D:\Anaconda3\Lib\site-packages\fsspec\spec.py:1307, in AbstractFileSystem.open(self, path, mode, block_size, cache_options, compression, **kwargs)
#    1305 else:
#    1306     ac = kwargs.pop("autocommit", not self._intrans)
# -> 1307     f = self._open(
#    1308         path,
#    1309         mode=mode,
#    1310         block_size=block_size,
#    1311         autocommit=ac,
#    1312         cache_options=cache_options,
#    1313         **kwargs,
#    1314     )
#    1315     if compression is not None:
#    1316         from fsspec.compression import compr
#
# File D:\Anaconda3\Lib\site-packages\fsspec\implementations\local.py:180, in LocalFileSystem._open(self, path, mode, block_size, **kwargs)
#     178 if self.auto_mkdir and "w" in mode:
#     179     self.makedirs(self._parent(path), exist_ok=True)
# --> 180 return LocalFileOpener(path, mode, fs=self, **kwargs)
#
# File D:\Anaconda3\Lib\site-packages\fsspec\implementations\local.py:302, in LocalFileOpener.__init__(self, path, mode, autocommit, fs, compression, **kwargs)
#     300 self.compression = get_compression(path, compression)
#     301 self.blocksize = io.DEFAULT_BUFFER_SIZE
# --> 302 self._open()
#
# File D:\Anaconda3\Lib\site-packages\fsspec\implementations\local.py:307, in LocalFileOpener._open(self)
#     305 if self.f is None or self.f.closed:
#     306     if self.autocommit or "w" not in self.mode:
# --> 307         self.f = open(self.path, mode=self.mode)
#     308         if self.compression:
#     309             compress = compr[self.compression]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/delli/Downloads/tiktok_dataset.csv'

# %%
#Calling the dataframe using head.Head will show the attributed value in the brackets.
df.head(10)

# %%
#columns function will call the names of the columns included in the dataframe.
df.columns

# %%
#rename function is used to rename the columns of the the dataframe.
df = df.rename(columns = {'#':'S_no'})
df

# %%
#This will tell the shape of the dataframe
df.shape

# %%
#Dropna function is used to drop the 'NaN' values in the dataframe.inplace is used to confirm that these changes will directly effect the original dataframe.
df.dropna(inplace = True)

# %%
df

# %%
df.shape

# %%
df.columns

# %%
df = df.rename(columns = {'video_duration_sec':'Duration','video_view_count':'Views','video_like_count':'Like','video_share_count':'Share','video_download_count':'Downloads','video_comment_count':'Comments'})
df.head(5)

# %%
#Drop function is used to drop the columns in the dataframe.Axis indicates that you want to drop the column named.
df = df.drop('video_transcription_text',axis = 1)

# %%
df.head(4)

# %%
#value count is used to count all the unique values in the particular column.
df['claim_status'].value_counts().head(20)

# %%
#astype is used to change the datatype of the column.
df['Views'] = df['Views'].astype(int)
df['Like'] = df['Like'].astype(int)
df['Share'] = df['Share'].astype(int)
df['Downloads'] = df['Downloads'].astype(int)
df['Comments'] = df['Comments'].astype(int)

# %%
#Defining a new variable to contain the dataframe with having duration above 50.
df_filtered = df[df['Duration']>=50]

# %%
df_filtered

# %%
#plotting a bar chart using plot method
colors = ('blue','cyan','green','magenta','red','yellow')
df_filtered['Duration'].value_counts().plot(kind = 'bar',color = colors,title = 'Videos of Duration Above 50',xlabel = 'Duration',ylabel = 'Count')

# %%
Duration = df_filtered['Duration']

# %%
Duration

# %%
plt.figure(figsize = (4,5))
plt.bar(Duration,align = 'center',height = 10)
plt.title('Videos of Duration more than 50s',weight = 'bold',color = 'red')
plt.show()

# %%
df

# %%
df.shape

# %%
df['verified_status'].value_counts().plot(kind = 'bar',color = colors,figsize = (4,4),title = 'Status of Videos')

# %%
df.head(10)

# %%
df = df.rename(columns = {'author_ban_status':'Ban_status'})

# %%
df

# %%
#Defining a new variable st for containing the count of banned users.
st=df['Ban_status'].value_counts()

# %%
print(st)

# %%
'''Converting the st variable firstly into dictionary using dict() method.Secondly converting the keys and values seperatly into list using list() method.
This is done to plot a pie chart which will help in understanding the data.'''
l = dict(st)
print(l)
l2 = list(l.keys())
l2
l3 = list(l.values())
l3

# %%
#Printing the lists
print(l2)
print(l3)

# %%
#Plotting the pie chart.
plt.figure(figsize = (4,4))
plt.pie(l3,labels = l2)
plt.axis('equal')
plt.title('Ban_Status of Tik Tok Influencers')
plt.show()

# %%
df

# %%
#Finding the mean of comments column.
df['Comments'].mean()

# %%
df['Downloads'].mean()

# %%
df['Share'].median()

# %%
df.to_excel('Tik Tok Analysis.xlsx')
