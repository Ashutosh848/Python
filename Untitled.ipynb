# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C://Users//delli//Downloads//archive//credit_card_transactions.csv")

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (1100702, 24)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud', 'merch_zipcode'],
#       dtype='object')

# %%
df1 = df.drop(columns = {'Unnamed: 0','trans_date_trans_time','unix_time','merch_zipcode','street',})

# %%
df1.head(10)
# Out:
#               cc_num                           merchant       category  \
# 0   2703186189652095         fraud_Rippin, Kub and Mann       misc_net
# 2     38859492057661               fraud_Lind-Buckridge  entertainment
# 4    375534208663984                fraud_Keeling-Crist       misc_pos
# 5   4767265376804500   fraud_Stroman, Hudson and Erdman  gas_transport
# 7   6011360759745864               fraud_Corwin-Collins  gas_transport
# 8   4922710831011201                   fraud_Herzog Ltd       misc_pos
# 9   2720830304681674  fraud_Schoen, Kuphal and Nitzsche    grocery_pos
# 10     4642894980163             fraud_Rutherford-Mertz    grocery_pos
# 11   377234009633447              fraud_Kerluke-Abshire   shopping_net
# 12   180042946491150                  fraud_Lockman Ltd    grocery_pos
#
#        amt     first       last gender                 city state    zip  \
# 0     4.97  Jennifer      Banks      F       Moravian Falls    NC  28654
# ...

# %%
df1
# Out:
#                       cc_num                             merchant  \
# 0           2703186189652095           fraud_Rippin, Kub and Mann
# 2             38859492057661                 fraud_Lind-Buckridge
# 4            375534208663984                  fraud_Keeling-Crist
# 5           4767265376804500     fraud_Stroman, Hudson and Erdman
# 7           6011360759745864                 fraud_Corwin-Collins
# ...                      ...                                  ...
# 1296669  4400011257587661852                 fraud_Stiedemann Inc
# 1296671     6011149206456997             fraud_Abernathy and Sons
# 1296672     3514865930894695                 fraud_Stiedemann Ltd
# 1296673     2720012583106919  fraud_Reinger, Weissnat and Strosin
# 1296674  4292902571056973207  fraud_Langosh, Wintheiser and Hyatt
#
#               category     amt        first       last gender  \
# 0             misc_net    4.97     Jennifer      Banks      F
# ...

# %%
df1 = df1.rename({'amt':'Amount'},axis = 1)

# %%
df1
# Out:
#                       cc_num                             merchant  \
# 0           2703186189652095           fraud_Rippin, Kub and Mann
# 2             38859492057661                 fraud_Lind-Buckridge
# 4            375534208663984                  fraud_Keeling-Crist
# 5           4767265376804500     fraud_Stroman, Hudson and Erdman
# 7           6011360759745864                 fraud_Corwin-Collins
# ...                      ...                                  ...
# 1296669  4400011257587661852                 fraud_Stiedemann Inc
# 1296671     6011149206456997             fraud_Abernathy and Sons
# 1296672     3514865930894695                 fraud_Stiedemann Ltd
# 1296673     2720012583106919  fraud_Reinger, Weissnat and Strosin
# 1296674  4292902571056973207  fraud_Langosh, Wintheiser and Hyatt
#
#               category  Amount        first       last gender  \
# 0             misc_net    4.97     Jennifer      Banks      F
# ...

# %%
df1.columns
# Out:
# Index(['cc_num', 'merchant', 'category', 'Amount', 'first', 'last', 'gender',
#        'city', 'state', 'zip', 'lat', 'long', 'city_pop', 'job', 'dob',
#        'trans_num', 'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
df['merchant'].value_counts().head(10)
# Out:
# merchant
# fraud_Kilback LLC                       3743
# fraud_Cormier LLC                       3108
# fraud_Schumm PLC                        3084
# fraud_Boyer PLC                         2985
# fraud_Kuhn LLC                          2971
# fraud_Dickinson Ltd                     2904
# fraud_Cummerata-Jones                   2363
# fraud_Connelly, Reichert and Fritsch    2320
# fraud_Bartoletti-Wunsch                 2307
# fraud_Jenkins, Hauck and Friesen        2306
# Name: count, dtype: int64

# %%
d = df1.drop(columns={'zip'})

# %%
d.head(10)
# Out:
#               cc_num                           merchant       category  \
# 0   2703186189652095         fraud_Rippin, Kub and Mann       misc_net
# 2     38859492057661               fraud_Lind-Buckridge  entertainment
# 4    375534208663984                fraud_Keeling-Crist       misc_pos
# 5   4767265376804500   fraud_Stroman, Hudson and Erdman  gas_transport
# 7   6011360759745864               fraud_Corwin-Collins  gas_transport
# 8   4922710831011201                   fraud_Herzog Ltd       misc_pos
# 9   2720830304681674  fraud_Schoen, Kuphal and Nitzsche    grocery_pos
# 10     4642894980163             fraud_Rutherford-Mertz    grocery_pos
# 11   377234009633447              fraud_Kerluke-Abshire   shopping_net
# 12   180042946491150                  fraud_Lockman Ltd    grocery_pos
#
#     Amount     first       last gender                 city state      lat  \
# 0     4.97  Jennifer      Banks      F       Moravian Falls    NC  36.0788
# ...

# %%
d
# Out:
#                       cc_num                             merchant  \
# 0           2703186189652095           fraud_Rippin, Kub and Mann
# 2             38859492057661                 fraud_Lind-Buckridge
# 4            375534208663984                  fraud_Keeling-Crist
# 5           4767265376804500     fraud_Stroman, Hudson and Erdman
# 7           6011360759745864                 fraud_Corwin-Collins
# ...                      ...                                  ...
# 1296669  4400011257587661852                 fraud_Stiedemann Inc
# 1296671     6011149206456997             fraud_Abernathy and Sons
# 1296672     3514865930894695                 fraud_Stiedemann Ltd
# 1296673     2720012583106919  fraud_Reinger, Weissnat and Strosin
# 1296674  4292902571056973207  fraud_Langosh, Wintheiser and Hyatt
#
#               category  Amount        first       last gender  \
# 0             misc_net    4.97     Jennifer      Banks      F
# ...

# %%
d['FullName'] = d['first']+d['last']
print(d.head(2))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:160, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'first'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 d['FullName'] = d['first']+d['last']
#       2 print(d.head(2))
#
# File D:\Anaconda3\Lib\site-packages\pandas\core\series.py:1040, in Series.__getitem__(self, key)
# ...

# %%
d
# Out:
# 0                 JenniferBanks
# 2                 EdwardSanchez
# 4                   TylerGarcia
# 5                JenniferConner
# 7                StevenWilliams
#                    ...
# 1296669           MarissaPowell
# 1296671            JeffreyWhite
# 1296672    ChristopherCastaneda
# 1296673            JosephMurray
# 1296674            JeffreySmith
# Length: 1100702, dtype: object

# %%
# Out:
#                       cc_num                             merchant  \
# 0           2703186189652095           fraud_Rippin, Kub and Mann
# 2             38859492057661                 fraud_Lind-Buckridge
# 4            375534208663984                  fraud_Keeling-Crist
# 5           4767265376804500     fraud_Stroman, Hudson and Erdman
# 7           6011360759745864                 fraud_Corwin-Collins
# ...                      ...                                  ...
# 1296669  4400011257587661852                 fraud_Stiedemann Inc
# 1296671     6011149206456997             fraud_Abernathy and Sons
# 1296672     3514865930894695                 fraud_Stiedemann Ltd
# 1296673     2720012583106919  fraud_Reinger, Weissnat and Strosin
# 1296674  4292902571056973207  fraud_Langosh, Wintheiser and Hyatt
#
#               category  Amount        first       last gender  \
# 0             misc_net    4.97     Jennifer      Banks      F
# ...
